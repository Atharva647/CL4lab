# %% [markdown]
# ### Assignment No.: 1
# ### Problem Statement: Import Data from different Sources such as (Excel, Sql Server, Oracle etc.) and load in        targeted system.
# ### Name of Student: Parkale Shreya Jagdish
# ### Roll No: 2447060
# ### Batch: C

# %%
pip install pandas sqlalchemy cx_Oracle pyodbc mysql-connector
# Out:
# ...
#      -------------------------------------- 213.2/213.2 kB 2.6 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 11.9/11.9 MB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp39-cp39-win_amd64.whl size=247946 sha256=c6f7e7f8b0968f8bd2ec18845868a56425783c3d7a5558be1c32cb2ca852e424
#   Stored in directory: c:\users\shrey\appdata\local\pip\cache\wheels\7b\14\39\5aad423666e827dfe9a1fbcd111ac17171e7c9865d570780ce
# Successfully built mysql-connector
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# ...

# %% [markdown]
# ### Import Data from Excel

# %%
import pandas as pd
# Load Excel file
data_excel = pd.read_excel('sales data.xlsx')
print(data_excel.head())
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25            8/23/2020        Games
# 1    France         46296.26   40319.41            5/15/2020        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16            6/26/2019  Electronics
# 4        UK         63979.04   56032.84           10/22/2019        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %%
data_excel
# Out:
#           country  order_value_EUR       cost                 date  \
# 0          Sweden         98320.37   77722.25            8/23/2020
# 1          France         46296.26   40319.41            5/15/2020
# 2        Portugal        140337.34  115708.14  2020-04-09 00:00:00
# 3          France        203604.46  175344.16            6/26/2019
# 4              UK         63979.04   56032.84           10/22/2019
# ...           ...              ...        ...                  ...
# 996        France         69126.50    55902.6  2019-08-12 00:00:00
# 997        France        140943.88  120633.87            5/28/2020
# 998        France        124784.67  106853.11            5/22/2020
# 999       Germany         61968.26   50690.04           12/27/2020
# 1000  Netherlands        172453.10  145688.38            6/24/2020
#
#          category                     customer_name    sales_manager  \
# 0           Games                    Konopelski LLC     Maxie Marrow
# ...

# %%
data_excel.head()
# Out:
#     country  order_value_EUR       cost                 date     category  \
# 0    Sweden         98320.37   77722.25            8/23/2020        Games
# 1    France         46296.26   40319.41            5/15/2020        Games
# 2  Portugal        140337.34  115708.14  2020-04-09 00:00:00   Appliances
# 3    France        203604.46  175344.16            6/26/2019  Electronics
# 4        UK         63979.04   56032.84           10/22/2019        Games
#
#      customer_name    sales_manager            sales_rep device_type  \
# 0   Konopelski LLC     Maxie Marrow   Tarrah Castelletti      Tablet
# 1       Wisoky Inc    Othello Bowes  Amelina Piscopiello      Tablet
# 2    Hegmann Group  Celine Tumasian        Corene Shirer          PC
# 3  Kirlin and Sons    Othello Bowes         Crysta Halls      Mobile
# 4   Schoen-Keeling  Jessamine Apark   Genevra Charrisson          PC
#
#      order_id
# 0  70-0511466
# 1  77-3489084
# 2  65-8218141
# 3  29-5478106
# 4  27-3437546

# %% [markdown]
# ### Import Data From SQL Server

# %%
pip install pymysql
# Out:
# ...
#      -------------------------------------- 45.0/45.0 kB 315.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (d:\users\shrey\anaconda3\lib\site-packages)

# %%
from sqlalchemy import create_engine
import pandas as pd

# URL-encoded password
engine = create_engine("mysql+pymysql://root:Atharva%40647@localhost:3306/Salesdb")
data_sql = pd.read_sql("SELECT * FROM Orders", engine)
print(data_sql.head())
# Out:
#    OrderID   CustomerName   OrderDate  Amount
# 0        1       John Doe  2025-01-15  250.50
# 1        2     Jane Smith  2025-01-16  175.75
# 2        3  Alice Johnson  2025-01-17  300.00
